# %%
from datasets import load_dataset

dataset = load_dataset("/home/rnanawa1/GeoLifeLearn/data/species25")
# Out:
# ...
# Resolving data files:   0%|          | 0/21635 [00:00<?, ?it/s]

# %%
dataset.push_to_hub("nrishabh/geolife")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/217 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/nrishabh/geolife/commit/c339d41594f96e5eb96f911ae9d282dfbe43aedb', commit_message='Upload dataset', commit_description='', oid='c339d41594f96e5eb96f911ae9d282dfbe43aedb', pr_url=None, pr_revision=None, pr_num=None)
